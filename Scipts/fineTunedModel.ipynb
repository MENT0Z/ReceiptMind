# %%
import cv2

# %%
import os
os.chdir("..")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Madan Raj Upadhyay\\Downloads\\Paddle'

# %%
# %cd PaddleOCR
# Out:
# Running cells with 'paddle_env (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Madan Raj Upadhyay/Downloads/Paddle/paddle_env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
# finetuned with db
# !python tools\infer\predict_system.py \
  --det_algorithm="DB++" \
  --det_model_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\infer" \
  --rec_model_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\en_PP-OCRv4_rec_infer" \
  --image_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\testImages\X00016469622.jpg" \
  --rec_char_dict_path=ppocr/utils/en_dict.txt \
  --use_gpu=False
# Out:
# [2025/12/30 13:27:29] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# ReduceMeanCheckIfOneDNNSupport
# [2025/12/30 13:27:31] ppocr DEBUG: dt_boxes num : 37, elapsed : 2.6798086166381836
# [2025/12/30 13:27:35] ppocr DEBUG: rec_res num  : 37, elapsed : 3.670719861984253
# [2025/12/30 13:27:35] ppocr DEBUG: 0  Predict time of C:\Users\Madan Raj Upadhyay\Downloads\Paddle\testImages\X00016469622.jpg: 6.375s
# [2025/12/30 13:27:35] ppocr DEBUG: YONGFATT ENTERPRISE, 0.967
# [2025/12/30 13:27:35] ppocr DEBUG: M0517726, 0.931
# [2025/12/30 13:27:35] ppocr DEBUG: NO 122124JALAN DEDAP 13, 0.898
# [2025/12/30 13:27:35] ppocr DEBUG: 81100JOHORBAHRU, 0.938
# [2025/12/30 13:27:35] ppocr DEBUG: TEL07-3523888, 0.984
# [2025/12/30 13:27:35] ppocr DEBUG: GSTID000849813504, 0.966
# [2025/12/30 13:27:35] ppocr DEBUG: SIMPLIFIED TAX INVOICE, 0.961
# [2025/12/30 13:27:35] ppocr DEBUG: CASH, 0.992
# [2025/12/30 13:27:35] ppocr DEBUG: DoC NO, 0.722
# [2025/12/30 13:27:35] ppocr DEBUG: CS00031663, 0.980
# [2025/12/30 13:27:35] ppocr DEBUG: 25/12/2018, 0.989
# [2025/12/30 13:27:35] ppocr DEBUG: USER, 0.996
# [2025/12/30 13:27:35] ppocr DEBUG: Ref., 0.843
# [2025/12/30 13:27:35] ppocr DEBUG: Amount, 0.989
# [2025/12/30 13:27:35] ppocr DEBUG: E8318, 0.908
# [2025/12/30 13:27:35] ppocr DEBUG: 8091, 0.989
# [2025/12/30 13:27:35] ppocr DEBUG: ELEGANT SCH TR BAG15, 0.891
# [2025/12/30 13:27:35] ppocr DEBUG: TotalQy, 0.941
# [2025/12/30 13:27:35] ppocr DEBUG: 8091, 0.991
# [2025/12/30 13:27:35] ppocr DEBUG: 80.91, 0.962
# [2025/12/30 13:27:35] ppocr DEBUG: Discount, 0.983
# [2025/12/30 13:27:35] ppocr DEBUG: 000, 0.926
# [2025/12/30 13:27:35] ppocr DEBUG: TotalGST, 0.856
# [2025/12/30 13:27:35] ppocr DEBUG: -001, 0.926
# [2025/12/30 13:27:35] ppocr DEBUG: 80.90, 0.994
# [2025/12/30 13:27:35] ppocr DEBUG: CASH, 0.994
# [2025/12/30 13:27:35] ppocr DEBUG: 100.00, 0.994
# [2025/12/30 13:27:35] ppocr DEBUG: 19.10, 0.991
# [2025/12/30 13:27:35] ppocr DEBUG: GST SUMMARY, 0.966
# [2025/12/30 13:27:35] ppocr DEBUG: AmtRM, 0.853
# [2025/12/30 13:27:35] ppocr DEBUG: TaxRM, 0.956
# [2025/12/30 13:27:35] ppocr DEBUG: SR, 0.982
# [2025/12/30 13:27:35] ppocr DEBUG: 80.91, 0.988
# [2025/12/30 13:27:35] ppocr DEBUG: 000, 0.965
# [2025/12/30 13:27:35] ppocr DEBUG: Total, 0.969
# [2025/12/30 13:27:35] ppocr DEBUG: 80.91, 0.989
# [2025/12/30 13:27:35] ppocr DEBUG: 0.00, 0.973
# [2025/12/30 13:27:35] ppocr DEBUG: The visualized image saved in ./inference_results\X00016469622.jpg
# [2025/12/30 13:27:35] ppocr INFO: The predict total time is 6.578954696655273
# INFO: Could not find files for the given pattern(s).
# c:\Users\Madan Raj Upadhyay\Downloads\Paddle\paddleOcr_old_version\Lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1230 13:27:27.240814 20908 onednn_context.cc:81] oneDNN v3.6.2

# %%
# finetuned with db++
# !python tools\infer\predict_system.py \
  --det_algorithm="DB++" \
  --det_model_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\infer_db++" \
  --rec_model_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\en_PP-OCRv4_rec_infer" \
  --image_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\testImages\test_02.jpg" \
  --rec_char_dict_path=ppocr/utils/en_dict.txt \
  --use_gpu=False
# Out:
# [2025/12/30 14:37:36] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# ReduceMeanCheckIfOneDNNSupport
# [2025/12/30 14:37:37] ppocr DEBUG: dt_boxes num : 23, elapsed : 1.1190030574798584
# [2025/12/30 14:37:39] ppocr DEBUG: rec_res num  : 23, elapsed : 1.8470335006713867
# [2025/12/30 14:37:39] ppocr DEBUG: 0  Predict time of C:\Users\Madan Raj Upadhyay\Downloads\Paddle\testImages\test_02.jpg: 2.979s
# [2025/12/30 14:37:39] ppocr DEBUG: Welcome to KFC, 0.921
# [2025/12/30 14:37:39] ppocr DEBUG: KFC, 0.995
# [2025/12/30 14:37:39] ppocr DEBUG: VAT#0051841, 0.982
# [2025/12/30 14:37:39] ppocr DEBUG: Order#, 0.997
# [2025/12/30 14:37:39] ppocr DEBUG: 3007, 0.999
# [2025/12/30 14:37:39] ppocr DEBUG: 930 Carrine, 0.953
# [2025/12/30 14:37:39] ppocr DEBUG: Chk 3007, 0.939
# [2025/12/30 14:37:39] ppocr DEBUG: 09May'18 15:03, 0.911
# [2025/12/30 14:37:39] ppocr DEBUG: 17.00, 0.988
# [2025/12/30 14:37:39] ppocr DEBUG: 4 Barbeque, 0.919
# [2025/12/30 14:37:39] ppocr DEBUG: 1 Fries reg, 0.879
# [2025/12/30 14:37:39] ppocr DEBUG: 4.25, 0.983
# [2025/12/30 14:37:39] ppocr DEBUG: Ketchup, 0.922
# [2025/12/30 14:37:39] ppocr DEBUG: 3.25, 0.986
# [2025/12/30 14:37:39] ppocr DEBUG: CASH, 0.993
# [2025/12/30 14:37:39] ppocr DEBUG: 20.00, 0.989
# [2025/12/30 14:37:39] ppocr DEBUG: CASH, 0.998
# [2025/12/30 14:37:39] ppocr DEBUG: 20.00, 0.991
# [2025/12/30 14:37:39] ppocr DEBUG: 3.1915%, 0.904
# [2025/12/30 14:37:39] ppocr DEBUG: 24.50, 0.994
# [2025/12/30 14:37:39] ppocr DEBUG: 24.50, 0.994
# [2025/12/30 14:37:39] ppocr DEBUG: 24.50, 0.993
# [2025/12/30 14:37:39] ppocr DEBUG: 930 Check Closed-, 0.924
# [2025/12/30 14:37:39] ppocr DEBUG: The visualized image saved in ./inference_results\test_02.jpg
# [2025/12/30 14:37:39] ppocr INFO: The predict total time is 3.0835068225860596
# INFO: Could not find files for the given pattern(s).
# c:\Users\Madan Raj Upadhyay\Downloads\Paddle\paddleOcr_old_version\Lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1230 14:37:34.985478  4600 onednn_context.cc:81] oneDNN v3.6.2

# %%
# !python tools\infer\predict_system.py \
  --det_algorithm="DB++" \
  --det_model_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\infer_det_pre" \
  --rec_model_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\en_PP-OCRv4_rec_infer" \
  --image_dir="C:\Users\Madan Raj Upadhyay\Downloads\Paddle\testImages\test_02.jpg" \
  --rec_char_dict_path=ppocr/utils/en_dict.txt \
  --use_gpu=False
# Out:
# [2025/12/30 14:34:14] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2025/12/30 14:34:15] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.32153940200805664
# [2025/12/30 14:34:17] ppocr DEBUG: rec_res num  : 36, elapsed : 2.593233346939087
# [2025/12/30 14:34:17] ppocr DEBUG: 0  Predict time of C:\Users\Madan Raj Upadhyay\Downloads\Paddle\testImages\test_02.jpg: 2.927s
# [2025/12/30 14:34:17] ppocr DEBUG: Welcome, 0.983
# [2025/12/30 14:34:17] ppocr DEBUG: to KFC, 0.873
# [2025/12/30 14:34:17] ppocr DEBUG: KFC, 0.995
# [2025/12/30 14:34:17] ppocr DEBUG: Store, 0.997
# [2025/12/30 14:34:17] ppocr DEBUG: VAT#0051841, 0.988
# [2025/12/30 14:34:17] ppocr DEBUG: #ID02, 0.872
# [2025/12/30 14:34:17] ppocr DEBUG: Order#, 0.998
# [2025/12/30 14:34:17] ppocr DEBUG: 3007, 0.999
# [2025/12/30 14:34:17] ppocr DEBUG: 930 Carrine, 0.961
# [2025/12/30 14:34:17] ppocr DEBUG: Chk 3007, 0.934
# [2025/12/30 14:34:17] ppocr DEBUG: 09May'18 15:03, 0.914
# [2025/12/30 14:34:17] ppocr DEBUG: 2 Popcorn Large @ 8.50, 0.927
# [2025/12/30 14:34:17] ppocr DEBUG: 17.00, 0.993
# [2025/12/30 14:34:17] ppocr DEBUG: 1 Fries reg, 0.904
# [2025/12/30 14:34:17] ppocr DEBUG: 4 Barbeque, 0.954
# [2025/12/30 14:34:17] ppocr DEBUG: 4.25, 0.986
# [2025/12/30 14:34:17] ppocr DEBUG: Ketchup, 0.988
# [2025/12/30 14:34:17] ppocr DEBUG: 1 Cola Med, 0.885
# [2025/12/30 14:34:17] ppocr DEBUG: 3.25, 0.987
# [2025/12/30 14:34:17] ppocr DEBUG: CASH, 0.997
# [2025/12/30 14:34:17] ppocr DEBUG: 20.00, 0.997
# [2025/12/30 14:34:17] ppocr DEBUG: CASH, 0.997
# [2025/12/30 14:34:17] ppocr DEBUG: 20.00, 0.997
# [2025/12/30 14:34:17] ppocr DEBUG: 3.1915%, 0.932
# [2025/12/30 14:34:17] ppocr DEBUG: A, 0.841
# [2025/12/30 14:34:17] ppocr DEBUG: 24.50, 0.997
# [2025/12/30 14:34:17] ppocr DEBUG: Sub Tota, 0.953
# [2025/12/30 14:34:17] ppocr DEBUG: 24.50, 0.961
# [2025/12/30 14:34:17] ppocr DEBUG: Total Cue, 0.789
# [2025/12/30 14:34:17] ppocr DEBUG: 24.50, 0.994
# [2025/12/30 14:34:17] ppocr DEBUG: ge Due, 0.926
# [2025/12/30 14:34:17] ppocr DEBUG: 15.50, 0.995
# [2025/12/30 14:34:17] ppocr DEBUG: -930 Check Closed-, 0.936
# [2025/12/30 14:34:17] ppocr DEBUG: -09May18 15:05, 0.883
# [2025/12/30 14:34:17] ppocr DEBUG: Visit kfcgr, 0.929
# [2025/12/30 14:34:17] ppocr DEBUG: The visualized image saved in ./inference_results\test_02.jpg
# [2025/12/30 14:34:17] ppocr INFO: The predict total time is 3.075695753097534
# INFO: Could not find files for the given pattern(s).
# c:\Users\Madan Raj Upadhyay\Downloads\Paddle\paddleOcr_old_version\Lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1230 14:34:14.108706 18036 onednn_context.cc:81] oneDNN v3.6.2

# %%
# !python.exe -m pip install --upgrade pip
# !pip install opencv-python
# Out:
# Requirement already satisfied: pip in c:\users\madan raj upadhyay\downloads\paddle\paddleocr_old_version\lib\site-packages (25.1.1)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Successfully installed pip-25.3
# Requirement already satisfied: opencv-python in c:\users\madan raj upadhyay\downloads\paddle\paddleocr_old_version\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\madan raj upadhyay\downloads\paddle\paddleocr_old_version\lib\site-packages (from opencv-python) (2.2.6)

# %%
import os
import json
import time
import subprocess
import sys

# ---------------- CONFIG ----------------
IMAGE_FOLDER = r"C:\Users\Madan Raj Upadhyay\Downloads\Paddle\testImages"
OUTPUT_FILE = "finetuned_results_new.json"

PADDLE_CMD_TEMPLATE = [
    "python",
    "tools/infer/predict_system.py",
    "--det_algorithm=DB++",
    "--det_model_dir=C:\\Users\\Madan Raj Upadhyay\\Downloads\\Paddle\\infer_det_pre",
    "--rec_model_dir=C:\\Users\\Madan Raj Upadhyay\\Downloads\\Paddle\\en_PP-OCRv4_rec_infer",
    "--rec_char_dict_path=ppocr/utils/en_dict.txt",
    "--use_gpu=False"
]
# ----------------------------------------

image_extensions = (".jpg", ".jpeg", ".png", ".bmp")
files = [f for f in os.listdir(IMAGE_FOLDER) if f.lower().endswith(image_extensions)]

all_results = {}

print(f"Starting fine-tuned OCR batch on {len(files)} images...")
print(f"Using interpreter: {sys.executable}")

for filename in files:
    img_path = os.path.join(IMAGE_FOLDER, filename)
    print(f"Processing: {filename}")

    try:
        start_time = time.time()

        cmd = PADDLE_CMD_TEMPLATE + [f"--image_dir={img_path}"]

        result = subprocess.run(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            encoding="utf-8"
        )

        latency = time.time() - start_time

        all_results[filename] = {
            "metadata": {
                "latency_sec": round(latency, 3),
                "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
                "return_code": result.returncode
            },
            "stdout": result.stdout,
            "stderr": result.stderr
        }

    except Exception as e:
        all_results[filename] = {
            "error": str(e)
        }

with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(all_results, f, ensure_ascii=False, indent=4)

print("-" * 40)
print(f"DONE! Results saved to: {OUTPUT_FILE}")
# Out:
# Starting fine-tuned OCR batch on 7 images...
# Using interpreter: c:\Users\Madan Raj Upadhyay\Downloads\Paddle\paddleOcr_old_version\Scripts\python.exe
# Processing: X00016469622.jpg
# Processing: X00016469623.jpg
# Processing: X51005255805.jpg
# Processing: X51008114282.jpg
# Processing: X51008123599.jpg
# Processing: X51008128062.jpg
# Processing: X51008164996.jpg
# ----------------------------------------
# DONE! Results saved to: finetuned_results_new.json

# %%
# Out:
# python: can't open file 'c:\\Users\\Madan Raj Upadhyay\\Downloads\\Paddle\\Scipts\\tools\\infer\\predict_system.py': [Errno 2] No such file or directory
